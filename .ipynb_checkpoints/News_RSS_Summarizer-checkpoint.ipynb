# %%
import feedparser
import torch
from transformers import BartForConditionalGeneration, BartTokenizer
from newspaper import Article
import os
from collections import defaultdict

# %%
model_name = "sshleifer/distilbart-cnn-12-6"
tokenizer = BartTokenizer.from_pretrained(model_name)
model = BartForConditionalGeneration.from_pretrained(model_name)

# %%
users = {
    "Alex Parker": {
        "interests": ["AI", "cybersecurity", "blockchain", "startups", "programming"],
        "sources": ["https://feeds.arstechnica.com/arstechnica/technology-lab.xml"],
        "country_sources": ["https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml"],  # USA-based tech news
    },
    "Priya Sharma": {
        "interests": ["Global markets", "startups", "fintech", "cryptocurrency", "economics"],
        "sources": ["https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=10000664"],
        "country_sources": ["https://economictimes.indiatimes.com/rssfeedsdefault.cms"], 
    },
    "Marco Rossi": {
        "interests": ["Football", "F1", "NBA", "Olympic sports", "esports"],
        "sources": ["https://www.espn.com/espn/rss/news.xml"],
        "country_sources": ["https://www.gazzetta.it/rss/home.xml"],  # Italy-based sports news
    },
    "Lisa Thompson": {
        "interests": ["Movies", "celebrity news", "TV shows", "music", "books"],
        "sources": ["https://www.tmz.com/rss.xml"],
        "country_sources": ["https://www.theguardian.com/uk/culture/rss"],  # UK-based entertainment news
    },
    "David Martinez": {
        "interests": ["Space exploration", "AI", "biotech", "physics", "renewable energy"],
        "sources": ["http://rss.sciam.com/ScientificAmerican-Global.xml"],
        "country_sources": ["https://www.elmundo.es/rss/ciencia-y-salud.xml"],  # Spain-based science news
    },
}

# %%
def fetch_articles(rss_urls):
    """Fetch articles from RSS feeds."""
    articles = []
    for url in rss_urls:
        feed = feedparser.parse(url)
        for entry in feed.entries[:6]:  # Fetch latest 5 articles
            articles.append({"title": entry.title, "link": entry.link})
    return articles

# %%
def summarize_article(url):
    """Fetch and summarize a news article from a given URL."""
    try:
        article = Article(url)
        article.download()
        article.parse()

        if not article.text:
            return "No content available."

        # Summarize using Hugging Face model
        inputs = tokenizer.encode("summarize: " + article.text[:2000], return_tensors="pt", truncation=True)
        with torch.no_grad():
            summary_ids = model.generate(inputs, max_length=200, min_length=100, num_beams=4)

        summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
        return summary
    except Exception as e:
        return f"Error fetching article: {str(e)}"

# %%
def generate_newsletter(user, articles):
    """Generate a structured personalized newsletter in Markdown format."""
    filename = f"{user.replace(' ', '_').lower()}_newsletter.md"
    
    # Generate a short summary at the top using article titles
    top_articles = [article["title"] for article in articles[:3]]  # Pick first 3 articles for summary
    top_summary = f"Here are the top trending news updates for {user}: " + "; ".join(top_articles) + "."

    # Organize articles based on interests
    categorized_articles = defaultdict(list)
    for article in articles:
        matched = False
        for interest in users[user]["interests"]:
            if interest.lower() in article["title"].lower():
                categorized_articles[interest].append(article)
                matched = True
        if not matched:
            categorized_articles["General"].append(article)  # Store unclassified articles here

    with open(filename, "w", encoding="utf-8") as f:
        f.write(f"# Personalized Newsletter for {user}\n\n")
        f.write(f"### Interests: {', '.join(users[user]['interests'])}\n\n")
        f.write(f"## Summary\n\n")
        f.write(f"{top_summary}\n\n")
        f.write(f"---\n\n")

        f.write(f"## News by Category\n\n")

        for category, articles in categorized_articles.items():
            f.write(f"### {category.capitalize()}\n\n")
            for article in articles:
                summary = summarize_article(article["link"])
                f.write(f"**{article['title']}**\n\n")
                f.write(f"{summary}\n\n")
                f.write(f"[Read full article]({article['link']})\n\n")
            f.write("---\n\n")

    print(f"Newsletter for {user} saved as {filename}")

# %%
for user, data in users.items():
    print(f"Generating newsletter for {user}...")
    user_articles = fetch_articles(data["sources"] + data.get("country_sources", []))  # Include country-specific sources
    generate_newsletter(user, user_articles)
# Out:
# Generating newsletter for Alex Parker...
# Newsletter for Alex Parker saved as alex_parker_newsletter.md
# Generating newsletter for Priya Sharma...
# Newsletter for Priya Sharma saved as priya_sharma_newsletter.md
# Generating newsletter for Marco Rossi...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       2 print(f"Generating newsletter for {user}...")
#       3 user_articles = fetch_articles(data["sources"] + data.get("country_sources", []))  # Include country-specific sources
# ----> 4 generate_newsletter(user, user_articles)
#
# Cell In[6], line 32, in generate_newsletter(user, articles)
#      30 f.write(f"### {category.capitalize()}\n\n")
#      31 for article in articles:
# ---> 32     summary = summarize_article(article["link"])
#      33     f.write(f"**{article['title']}**\n\n")
#      34     f.write(f"{summary}\n\n")
#
# Cell In[5], line 14, in summarize_article(url)
#      12 inputs = tokenizer.encode("summarize: " + article.text[:2000], return_tensors="pt", truncation=True)
#      13 with torch.no_grad():
# ---> 14     summary_ids = model.generate(inputs, max_length=200, min_length=100, num_beams=4)
#      16 summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
#      17 return summary
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\generation\utils.py:1953, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1945     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1946         input_ids=input_ids,
#    1947         expand_size=generation_config.num_beams,
#    1948         is_encoder_decoder=self.config.is_encoder_decoder,
#    1949         **model_kwargs,
#    1950     )
#    1952     # 14. run beam sample
# -> 1953     result = self._beam_search(
#    1954         input_ids,
#    1955         beam_scorer,
#    1956         logits_processor=prepared_logits_processor,
#    1957         logits_warper=prepared_logits_warper,
#    1958         stopping_criteria=prepared_stopping_criteria,
#    1959         generation_config=generation_config,
#    1960         synced_gpus=synced_gpus,
#    1961         **model_kwargs,
#    1962     )
#    1964 elif generation_mode == GenerationMode.GROUP_BEAM_SEARCH:
#    1965     # 11. prepare beam search scorer
#    1966     beam_scorer = BeamSearchScorer(
#    1967         batch_size=batch_size,
#    1968         num_beams=generation_config.num_beams,
#    (...)
#    1974         max_length=generation_config.max_length,
#    1975     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\generation\utils.py:2914, in GenerationMixin._beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, generation_config, synced_gpus, logits_warper, **model_kwargs)
#    2911     outputs = stack_model_outputs(outputs_per_sub_batch)
#    2913 else:  # Unchanged original behavior
# -> 2914     outputs = self(
#    2915         **model_inputs,
#    2916         return_dict=True,
#    2917         output_attentions=output_attentions,
#    2918         output_hidden_states=output_hidden_states,
#    2919     )
#    2921 if synced_gpus and this_peer_finished:
#    2922     cur_len = cur_len + 1
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\bart\modeling_bart.py:1747, in BartForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1742     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1743         decoder_input_ids = shift_tokens_right(
#    1744             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1745         )
# -> 1747 outputs = self.model(
#    1748     input_ids,
#    1749     attention_mask=attention_mask,
#    1750     decoder_input_ids=decoder_input_ids,
#    1751     encoder_outputs=encoder_outputs,
#    1752     decoder_attention_mask=decoder_attention_mask,
#    1753     head_mask=head_mask,
#    1754     decoder_head_mask=decoder_head_mask,
#    1755     cross_attn_head_mask=cross_attn_head_mask,
#    1756     past_key_values=past_key_values,
#    1757     inputs_embeds=inputs_embeds,
#    1758     decoder_inputs_embeds=decoder_inputs_embeds,
#    1759     use_cache=use_cache,
#    1760     output_attentions=output_attentions,
#    1761     output_hidden_states=output_hidden_states,
#    1762     return_dict=return_dict,
#    1763 )
#    1765 lm_logits = self.lm_head(outputs[0])
#    1766 lm_logits = lm_logits + self.final_logits_bias.to(lm_logits.device)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\bart\modeling_bart.py:1633, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1626     encoder_outputs = BaseModelOutput(
#    1627         last_hidden_state=encoder_outputs[0],
#    1628         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1629         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1630     )
#    1632 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1633 decoder_outputs = self.decoder(
#    1634     input_ids=decoder_input_ids,
#    1635     attention_mask=decoder_attention_mask,
#    1636     encoder_hidden_states=encoder_outputs[0],
#    1637     encoder_attention_mask=attention_mask,
#    1638     head_mask=decoder_head_mask,
#    1639     cross_attn_head_mask=cross_attn_head_mask,
#    1640     past_key_values=past_key_values,
#    1641     inputs_embeds=decoder_inputs_embeds,
#    1642     use_cache=use_cache,
#    1643     output_attentions=output_attentions,
#    1644     output_hidden_states=output_hidden_states,
#    1645     return_dict=return_dict,
#    1646 )
#    1648 if not return_dict:
#    1649     return decoder_outputs + encoder_outputs
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\bart\modeling_bart.py:1486, in BartDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1473     layer_outputs = self._gradient_checkpointing_func(
#    1474         decoder_layer.__call__,
#    1475         hidden_states,
#    (...)
#    1483         use_cache,
#    1484     )
#    1485 else:
# -> 1486     layer_outputs = decoder_layer(
#    1487         hidden_states,
#    1488         attention_mask=attention_mask,
#    1489         encoder_hidden_states=encoder_hidden_states,
#    1490         encoder_attention_mask=encoder_attention_mask,
#    1491         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1492         cross_attn_layer_head_mask=(
#    1493             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1494         ),
#    1495         past_key_value=past_key_value,
#    1496         output_attentions=output_attentions,
#    1497         use_cache=use_cache,
#    1498     )
#    1499 hidden_states = layer_outputs[0]
#    1501 if use_cache:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\bart\modeling_bart.py:791, in BartDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     789 # cross_attn cached key/values tuple is at positions 3,4 of present_key_value tuple
#     790 cross_attn_past_key_value = past_key_value[-2:] if past_key_value is not None else None
# --> 791 hidden_states, cross_attn_weights, cross_attn_present_key_value = self.encoder_attn(
#     792     hidden_states=hidden_states,
#     793     key_value_states=encoder_hidden_states,
#     794     attention_mask=encoder_attention_mask,
#     795     layer_head_mask=cross_attn_layer_head_mask,
#     796     past_key_value=cross_attn_past_key_value,
#     797     output_attentions=output_attentions,
#     798 )
#     799 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     800 hidden_states = residual + hidden_states
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\bart\modeling_bart.py:603, in BartSdpaAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     599 is_causal = True if self.is_causal and attention_mask is None and tgt_len > 1 else False
#     601 # NOTE: SDPA with memory-efficient backend is currently (torch==2.1.2) bugged when using non-contiguous inputs and a custom attn_mask,
#     602 # but we are fine here as `_shape` do call `.contiguous()`. Reference: https://github.com/pytorch/pytorch/issues/112577
# --> 603 attn_output = torch.nn.functional.scaled_dot_product_attention(
#     604     query_states,
#     605     key_states,
#     606     value_states,
#     607     attn_mask=attention_mask,
#     608     dropout_p=self.dropout if self.training else 0.0,
#     609     is_causal=is_causal,
#     610 )
#     612 if attn_output.size() != (bsz, self.num_heads, tgt_len, self.head_dim):
#     613     raise ValueError(
#     614         f"`attn_output` should be of size {(bsz, self.num_heads, tgt_len, self.head_dim)}, but is"
#     615         f" {attn_output.size()}"
#     616     )
#
# KeyboardInterrupt:
